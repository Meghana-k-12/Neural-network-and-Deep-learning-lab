# %% [markdown]
# Experiment No: 5
#
# Title: Develop a Neural Network to Classify Handwritten Digits (MNIST) and Visualize Accuracy/Loss Curves
#
# Aim:
#
# To develop a neural network model for classifying handwritten digits using the MNIST dataset and visualize training accuracy and loss curves.
#
# Procedure:
#
# 1.Import Libraries
# Import TensorFlow, Keras, and Matplotlib.
#
# 2.Load Dataset
# Load the MNIST dataset containing handwritten digit images.
#
# 3.Preprocess Data
# Normalize pixel values (0–255 → 0–1) and reshape if required.
#
# 4.Build Neural Network Model
# Create a Sequential model with input, hidden, and output layers.
#
# 5.Compile Model
# Define optimizer, loss function, and evaluation metrics.
#
# 6.Train Model
# Train the model using training data and store training history.
#
# 7.Evaluate Model
# Test the model on unseen data.
#
# 8.Visualize Results
# Plot accuracy and loss curves using Matplotlib.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Step 2: Normalize data
X_train = X_train / 255.0
X_test = X_test / 255.0

# Step 3: Build Neural Network
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Step 4: Compile model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Step 5: Train model
history = model.fit(X_train, y_train, epochs=5, validation_split=0.1)



# Step 6: Evaluate model
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_acc)

# ---------------- VISUALIZATION ----------------

# Visualization 1: Sample test images with predictions
predictions = model.predict(X_test)

plt.figure(figsize=(8,8))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i], cmap='gray')
    plt.title(f"Predicted: {np.argmax(predictions[i])}")
    plt.axis('off')
plt.show()

# Visualization 2: Accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# Visualization 3: Loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9218 - loss: 0.2740 - val_accuracy: 0.9637 - val_loss: 0.1228
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9639 - loss: 0.1195 - val_accuracy: 0.9713 - val_loss: 0.0912
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9744 - loss: 0.0831 - val_accuracy: 0.9767 - val_loss: 0.0808
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9816 - loss: 0.0614 - val_accuracy: 0.9740 - val_loss: 0.0825
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9855 - loss: 0.0468 - val_accuracy: 0.9768 - val_loss: 0.0774
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9760 - loss: 0.0784
# Test Accuracy: 0.9760000109672546
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# Result:
#
# Successfully developed a neural network for handwritten digit classification using the MNIST dataset. The model achieved high accuracy, and performance was effectively visualized using accuracy and loss curves.
